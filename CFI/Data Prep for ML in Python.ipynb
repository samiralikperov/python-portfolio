# %% [markdown]
# # Importing & FIltering Data

# %%
# import libraries

import pandas as pd
import numpy as np

# %% [markdown]
# ### Exercise 1  - Importing our data

# %% [markdown]
# Import the csv file titled "phone_marketplace_dataset_cleaning_set.csv" and set it as a dataframe. This dataset contains information on used phone sales that happened in various marketplace platforms.
#
# Task:
# - Use the correct pandas function to import the csv file as a dataframe
# - Assign the imported dataframe to a variable

# %%
# Import the phone_marketplace_dataset_cleaning_set.csv file into a dataframe
phone_df = pd.read_csv('phone_marketplace_dataset_cleaning_set.csv')
phone_df.head()
# Out:
#     price  year_made       name  battery_life_percentage  storage  \
# 0   551.0       2019  iPhone_11                       74       64
# 1   822.0       2020  iPhone_12                       94      128
# 2  1008.0       2022  iPhone_14                       97      256
# 3     NaN       2021  iPhone_13                       90      128
# 4   839.0       2020  iPhone_12                       91      256
#
#   magnet_charging  marketplace  years_owned  visible_scratches pro  \
# 0              no       kijiji            2                  9  no
# 1             yes   craigslist            2                  6  no
# 2             yes  craigslist!            0                  2  no
# 3             yes   craigslist            2                  2  no
# 4             yes       kijiji            1                  5  no
#
#    original_sale_price  #_of_previous_owners  megapixel
# 0                  747                     1         12
# ...

# %% [markdown]
# ### Exercise 2  - Conditional Filtering

# %% [markdown]
# We realized that there may be potential errors in the csv file in which we must deal with. Luckily, we are able to find out the errors came from data which came from craigslist.
#
# Task:
# - Filter for data that have craigslist as a marketplace
# - From the data that have craigslist as a marketplace, filter for only iPhone 11s

# %%
# Filter the data that has craigstlist as marketplace
craiglist_filter = phone_df[phone_df['marketplace'].str.contains('craigslist')]
craiglist_filter
# Out:
#       price  year_made       name  battery_life_percentage  storage  \
# 1     822.0       2020  iPhone_12                       94      128
# 2    1008.0       2022  iPhone_14                       97      256
# 3       NaN       2021  iPhone_13                       90      128
# 5     485.0       2019  iPhone_11                       72      256
# 8    1090.0       2024  iPhone_14                       92      128
# ..      ...        ...        ...                      ...      ...
# 338   670.0       2020  iPhone_12                       83      128
# 342  1231.0       2023  iPhone_14                       97      256
# 343     NaN       2022  iPhone_14                       99       64
# 344  1326.0       2022  iPhone_14                       91       64
# 347  1340.0       2022  iPhone_14                      100      256
#
#     magnet_charging  marketplace  years_owned  visible_scratches  pro  \
# 1               yes   craigslist            2                  6   no
# ...

# %%
# Add an additional filter for iphone 11 only.
craiglist_filter_iph_11 = phone_df[(phone_df['marketplace'].str.contains('craigslist')) & (phone_df['name'].str.contains('iPhone_11')) ]  
craiglist_filter_iph_11
# Out:
#      price  year_made       name  battery_life_percentage  storage  \
# 5    485.0       2019  iPhone_11                       72      256
# 10   507.0       2019  iPhone_11                       74      128
# 17     NaN       2019  iPhone_11                       87      128
# 47   551.0       2019  iPhone_11                       76      128
# 56   576.0       2019  iPhone_11                       71       64
# 63   501.0       2019  iPhone_11                       83       64
# 99   557.0       2019  iPhone_11                       72      128
# 107  446.0       2019  iPhone_11                       90      256
# 111  436.0       2019  iPhone_11                       72      256
# 116  556.0       2019  iPhone_11                       73      128
# 119  542.0       2019  iPhone_11                       79      128
# 141  402.0       2019  iPhone_11                       75      256
# 148  530.0       2019  iPhone_11                       87       64
# ...

# %% [markdown]
# # Data Validation

# %% [markdown]
# ### Exercise 1 (Basic) - Understanding the data type of columns

# %% [markdown]
# Find the data type of each column, for each column that is categorical list out their unique values, and check value range for each column that is numerical
#
# Task:
# - Import data
# - Explore data types
# - Explore value ranges

# %%
# Import data to a pandas dataframe
df_phone = pd.read_csv('phone_marketplace_dataset_cleaning_set.csv')
df_phone
# Out:
#       price  year_made       name  battery_life_percentage  storage  \
# 0     551.0       2019  iPhone_11                       74       64
# 1     822.0       2020  iPhone_12                       94      128
# 2    1008.0       2022  iPhone_14                       97      256
# 3       NaN       2021  iPhone_13                       90      128
# 4     839.0       2020  iPhone_12                       91      256
# ..      ...        ...        ...                      ...      ...
# 344  1326.0       2022  iPhone_14                       91       64
# 345   458.0       2019  iPhone_11                       75      256
# 346   487.0       2019  iPhone_11                       87      256
# 347  1340.0       2022  iPhone_14                      100      256
# 348  1144.0       2021  iPhone_13                       94      128
#
#     magnet_charging  marketplace  years_owned  visible_scratches  pro  \
# 0                no       kijiji            2                  9   no
# ...

# %%
# Finding out data type of each column
df_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   price                    343 non-null    float64
#  1   year_made                349 non-null    int64
#  2   name                     349 non-null    object
#  3   battery_life_percentage  349 non-null    int64
#  4   storage                  349 non-null    int64
#  5   magnet_charging          349 non-null    object
#  6   marketplace              349 non-null    object
#  7   years_owned              349 non-null    int64
#  8   visible_scratches        349 non-null    int64
#  9   pro                      349 non-null    object
#  10  original_sale_price      349 non-null    int64
#  11  #_of_previous_owners     349 non-null    int64
#  12  megapixel                349 non-null    int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 35.6+ KB

# %%
# Explore the range of values in the numerical columns
df_phone.describe()
# Out:
#              price    year_made  battery_life_percentage     storage  \
# count   343.000000   349.000000               349.000000  349.000000
# mean    879.096210  2020.538682                88.607450  148.171920
# std     304.855338     1.182642                 7.550067   79.229727
# min     402.000000  2019.000000                70.000000   64.000000
# 25%     595.000000  2019.000000                84.000000   64.000000
# 50%     856.000000  2021.000000                91.000000  128.000000
# 75%    1121.500000  2022.000000                94.000000  256.000000
# max    1499.000000  2024.000000               100.000000  256.000000
#
#        years_owned  visible_scratches  original_sale_price  \
# count   349.000000         349.000000           349.000000
# mean      1.495702           3.002865           965.103152
# std       1.242499           2.566919           277.363067
# min       0.000000           0.000000           408.000000
# ...

# %% [markdown]
# ### Exercise 2 (Advanced) - Exploring Column Values

# %% [markdown]
# Find the value count of each categorical column
#
# Task:
# - For each categorical column, find the count of each value
# - For each categorical column, return the unique values.
# - Hint: use a for loop to go through each column

# %%
# Define a list of category columns
cat_cols = ['name', 'magnet_charging', 'marketplace', 'pro']

# %%
# Using a loop to find all the unique values of a categorical column
for i in cat_cols:
    print(i,df_phone[i].unique())
# Out:
# name ['iPhone_11' 'iPhone_12' 'iPhone_14' 'iPhone_13']
# magnet_charging ['no' 'yes']
# marketplace ['kijiji' 'craigslist' 'craigslist!' 'facebook' 'facebook!' 'kijiji!']
# pro ['no' 'yes']

# %%
# Using a for loop find number of instances of each unique value of each categorical column
for i in cat_cols:
    print(i, df_phone[i].value_counts(), "\n")
# Out:
# name name
# iPhone_14    94
# iPhone_11    89
# iPhone_12    85
# iPhone_13    81
# Name: count, dtype: int64
#
# magnet_charging magnet_charging
# yes    260
# no      89
# Name: count, dtype: int64
#
# marketplace marketplace
# facebook       125
# craigslist     110
# kijiji         106
# craigslist!      3
# facebook!        3
# kijiji!          2
# Name: count, dtype: int64
#
# pro pro
# no     271
# yes     78
# Name: count, dtype: int64

# %% [markdown]
# # Cleaning Data & Imputation

# %% [markdown]
# ### Exercise 1 - Removing Unwanted Strings

# %% [markdown]
# Once again, we are working with the phone dataset. However, as you know we identified a few problems.
#
# Task:
# - Explore the unique values in the marketplace column, identify the typos, and fix them.

# %%
# Import data to a pandas dataframe
df_phone = pd.read_csv('phone_marketplace_dataset_cleaning_set.csv')
df_phone
# Out:
#       price  year_made       name  battery_life_percentage  storage  \
# 0     551.0       2019  iPhone_11                       74       64
# 1     822.0       2020  iPhone_12                       94      128
# 2    1008.0       2022  iPhone_14                       97      256
# 3       NaN       2021  iPhone_13                       90      128
# 4     839.0       2020  iPhone_12                       91      256
# ..      ...        ...        ...                      ...      ...
# 344  1326.0       2022  iPhone_14                       91       64
# 345   458.0       2019  iPhone_11                       75      256
# 346   487.0       2019  iPhone_11                       87      256
# 347  1340.0       2022  iPhone_14                      100      256
# 348  1144.0       2021  iPhone_13                       94      128
#
#     magnet_charging  marketplace  years_owned  visible_scratches  pro  \
# 0                no       kijiji            2                  9   no
# ...

# %%
# Explore the unique values in the marketplace column
un_val = df_phone['marketplace'].value_counts()
un_val
# Out:
# marketplace
# facebook       125
# craigslist     110
# kijiji         106
# craigslist!      3
# facebook!        3
# kijiji!          2
# Name: count, dtype: int64

# %%
#Replace or remove all ! in the marketplace column
df_phone['marketplace'] = df_phone['marketplace'].str.replace('!','')
df_phone['marketplace'].value_counts()
# Out:
# marketplace
# facebook      128
# craigslist    113
# kijiji        108
# Name: count, dtype: int64

# %% [markdown]
# ### Exercise 2 - Imputing Nulls with Appropriate Values

# %% [markdown]
# Identify the column that has null values and populate the values using a basic imputation method of your choice.
#
# Task:
# - Identify the columns that need to be dealt with
# - Populate missing values with a basic imputation method of your choice

# %%
df_phone.isna().sum()
# Out:
# price                      6
# year_made                  0
# name                       0
# battery_life_percentage    0
# storage                    0
# magnet_charging            0
# marketplace                0
# years_owned                0
# visible_scratches          0
# pro                        0
# original_sale_price        0
# #_of_previous_owners       0
# megapixel                  0
# dtype: int64

# %%
# Check the rows that are null
df_null = df_phone[df_phone['price'].isnull()]
df_null
# Out:
#      price  year_made       name  battery_life_percentage  storage  \
# 3      NaN       2021  iPhone_13                       90      128
# 17     NaN       2019  iPhone_11                       87      128
# 92     NaN       2022  iPhone_14                       94      256
# 227    NaN       2021  iPhone_13                       90       64
# 254    NaN       2020  iPhone_12                       83       64
# 343    NaN       2022  iPhone_14                       99       64
#
#     magnet_charging marketplace  years_owned  visible_scratches  pro  \
# 3               yes  craigslist            2                  2   no
# 17               no  craigslist            4                  1   no
# 92              yes  craigslist            0                  1   no
# 227             yes  craigslist            2                  2   no
# 254             yes  craigslist            1                  0  yes
# 343             yes  craigslist            0                  0  yes
#
# ...

# %%
#Find phone price averages (returned as series)
iphone_avg = df_phone.groupby('name') ['price'].mean()
iphone_avg
# Out:
# name
# iPhone_11     495.477273
# iPhone_12     758.202381
# iPhone_13    1013.164557
# iPhone_14    1241.293478
# Name: price, dtype: float64

# %%
df_phone['price'] = np.where(np.isnan(df_phone['price']), iphone_avg.loc[df_phone['name']], df_phone['price'])
df_phone
# Out:
#            price  year_made       name  battery_life_percentage  storage  \
# 0     551.000000       2019  iPhone_11                       74       64
# 1     822.000000       2020  iPhone_12                       94      128
# 2    1008.000000       2022  iPhone_14                       97      256
# 3    1013.164557       2021  iPhone_13                       90      128
# 4     839.000000       2020  iPhone_12                       91      256
# ..           ...        ...        ...                      ...      ...
# 344  1326.000000       2022  iPhone_14                       91       64
# 345   458.000000       2019  iPhone_11                       75      256
# 346   487.000000       2019  iPhone_11                       87      256
# 347  1340.000000       2022  iPhone_14                      100      256
# 348  1144.000000       2021  iPhone_13                       94      128
#
#     magnet_charging marketplace  years_owned  visible_scratches  pro  \
# ...

# %%
# Checking to see if anymore null values are left
df_phone.isna().sum()
# Out:
# price                      0
# year_made                  0
# name                       0
# battery_life_percentage    0
# storage                    0
# magnet_charging            0
# marketplace                0
# years_owned                0
# visible_scratches          0
# pro                        0
# original_sale_price        0
# #_of_previous_owners       0
# megapixel                  0
# dtype: int64

# %% [markdown]
# # EDA - Single Variable Analysis (Univariate Analysis)

# %% [markdown]
# ### Exercise 1 (Basic) - Visuals for Categorical Features

# %% [markdown]
# Create a bar chart to display the transmission type of SUVs
#
# Task:
# - Find the count of each transmission type for SUVs
# - Create a bar chart displaying the above

# %%
# import data
df_cars = pd.read_csv('indian_cars_dataset.csv')
df_cars.head()
# Out:
#    ending_price  starting_price  reviews_count  max_torque_nm  max_torque_rpm  \
# 0        583000          399000             51           89.0            3500
# 1       1396000          799000             86          136.8            4400
# 2       1603000         1353000            242          300.0            2800
# 3       2458000         1318000            313          450.0            2800
# 4       2390000         1199000            107          400.0            2750
#
#    max_power_bhp  max_power_rp  fuel_tank_capacity  no_cylinder  rating  \
# 0          65.71          5500                27.0            3     4.5
# 1         101.65          6000                48.0            4     4.5
# 2         130.00          3750                57.0            4     4.5
# 3         182.38          3500                60.0            4     4.5
# 4         172.45          3500                57.0            4     4.5
#
# ...

# %%
# libraries for visualization. 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# filter for SUVs

suv_df = df_cars[df_cars['body_type'] == 'SUV']
suv_df.head()
# Out:
#    ending_price  starting_price  reviews_count  max_torque_nm  max_torque_rpm  \
# 1       1396000          799000             86          136.8            4400
# 2       1603000         1353000            242          300.0            2800
# 3       2458000         1318000            313          450.0            2800
# 4       2390000         1199000            107          400.0            2750
# 5       4957000         3240000             99          500.0            2800
#
#    max_power_bhp  max_power_rp  fuel_tank_capacity  no_cylinder  rating  \
# 1         101.65          6000                48.0            4     4.5
# 2         130.00          3750                57.0            4     4.5
# 3         182.38          3500                60.0            4     4.5
# 4         172.45          3500                57.0            4     4.5
# 5         201.15          3400                80.0            4     4.5
#
# ...

# %%
# count values of each transmition type for SUVs
suv_df['transmission_type'].value_counts()
# Out:
# transmission_type
# Automatic    76
# Manual        9
# Name: count, dtype: int64

# %%
# plot the count plot

data = df_cars[df_cars['body_type'] == 'SUV']['transmission_type']
countplot = sns.countplot(x = data)

# %% [markdown]
# ### Exercise 2 (Basic) - Visuals for Numeric Features

# %% [markdown]
# Create two visuals that displays the distribution of the starting price of cars based on transmission type. Then find the average starting price for each transmission type
#
# Task:
# - Plot the distribution of starting price for each transmission type in a histogram
# - Print the average starting price for each transmission type

# %%
# plot the distribution for manual transmission

histplot = sns.histplot(data = df_cars[df_cars['transmission_type']=='Manual'], x ='starting_price', bins = 10)
# Out:
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# plot the distribution for automatic transmission

histplot = sns.histplot(data = df_cars[df_cars['transmission_type']=='Automatic'], x ='starting_price', bins = 10)
# Out:
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# mean starting price of each transmission type
avg_automatic = df_cars[df_cars['transmission_type']=='Automatic']['starting_price'].mean()
avg_manual = df_cars[df_cars['transmission_type']=='Manual']['starting_price'].mean()

print(f"Mean for Automatic is: {round(avg_automatic,2)}")
print(f"Mean for Manual is: {round(avg_manual,2)}")
# Out:
# Mean for Automatic is: 10446344.83
# Mean for Manual is: 3427413.79

# %% [markdown]
# # EDA - Multivariate Analysis

# %% [markdown]
# ### Exercise 1- Creating plots and statistics to find relationships between continuous data

# %% [markdown]
# Using descriptive statistics and scatter plots, determine the relationship between starting_price and ending_price. How do they differ?
#
# Task:
# - Create descriptive statistics for starting_price and ending price.
# - Create a scatter plot to illustrate the relationship between starting_price and ending_price.
# - What differences can you observe?

# %%
df_cars.head()
# Out:
#    ending_price  starting_price  reviews_count  max_torque_nm  max_torque_rpm  \
# 0        583000          399000             51           89.0            3500
# 1       1396000          799000             86          136.8            4400
# 2       1603000         1353000            242          300.0            2800
# 3       2458000         1318000            313          450.0            2800
# 4       2390000         1199000            107          400.0            2750
#
#    max_power_bhp  max_power_rp  fuel_tank_capacity  no_cylinder  rating  \
# 0          65.71          5500                27.0            3     4.5
# 1         101.65          6000                48.0            4     4.5
# 2         130.00          3750                57.0            4     4.5
# 3         182.38          3500                60.0            4     4.5
# 4         172.45          3500                57.0            4     4.5
#
# ...

# %%
# - Create descriptive statistics for starting_price and ending price. 

df_cars[['starting_price','ending_price']].describe().applymap('{:,.0f}'.format)
# Out:
# C:\Users\alikp\AppData\Local\Temp\ipykernel_17352\322713786.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_cars[['starting_price','ending_price']].describe().applymap('{:,.0f}'.format)
#       starting_price ending_price
# count            203          203
# mean       9,443,640   11,120,054
# std       13,570,354   15,517,463
# min          339,000      361,000
# 25%          945,500    1,407,500
# 50%        4,312,000    4,600,000
# 75%       11,600,000   15,750,000
# max       70,600,000   90,000,000

# %%
# Create a scatter plot to illustrate the relationship between starting_price and ending_price.
sns.scatterplot(data=df_cars, x="starting_price", y="ending_price")
plt.show()

# %%
# What differences can you observe?  
# Based on the scatterplot, the starting and ending prices are strongly positively correlated, and they are quite similar to each other. 
# Additionally, the minimum, mean, and maximum ending prices are all higher than the starting prices.

# %% [markdown]
# ### Exercise 2 - Creating plots to find relationships between categorical & categorical data

# %% [markdown]
# Using plots, determine the relationship between starting_price and fuel_type / transmission_type. What are the trends?
#
# Task:
# - Create multilevel box chart of starting price by transmission_type and fuel_type
# - What insights can you observe?

# %%
sns.boxplot(data=df_cars, x="fuel_type", y="starting_price", hue = "transmission_type").set(title='Fuel Type vs Starting Price')
plt.show()

# %%
# What insights can you observe?

# Manual cars generally have lower starting prices compared to automatic cars, regardless of the model.
# Electric cars do not offer a manual option, and CNG cars do not have an automatic option.
# There is a significant price difference between starting prices of automatic and manual cars.
# The black lines, which indicate the spread of the data for each category, show that petrol car prices have high variability,
#  with many outliers and a larger interquartile range.

# %% [markdown]
# # One Hot Encoding

# %% [markdown]
# ### Exercise 1 (Basic) Import & Identify Categorical Variables

# %% [markdown]
# For these exercises, you will be working with the well known breastcancer dataset. There are a number of features being used to predict the target variable, whether there is recurrence or no-recurrence of breastcancer.
#
# Source: UMCIO, Ljulljana, Yugoslavia. M. Zwitter & M. Soklic.
# https://archive.ics.uci.edu/ml/datasets/Breast+Cancer
#
# Follow the below steps to complete the one hot encoding exercise:
# - Import the breastcancer dataset into a dataframe
# - Find out what column types exist in the dataset
# - Return a list of object (category) columns
# - Explore the unique values that exist in each column. What unique values exist in the node-caps column?

# %%
#Import the csv file using the pre-populated code
bc_df = pd.read_csv('breastcancer_dataset.csv')
bc_df.head()
# Out:
#      age menopause tumor_size inv_nodes node_caps  deg_malig breast  \
# 0  40-49   premeno      15-19       0-2       yes          3  right
# 1  50-59      ge40      15-19       0-2        no          1  right
# 2  50-59      ge40      35-39       0-2        no          2   left
# 3  40-49   premeno      35-39       0-2       yes          3  right
# 4  40-49   premeno      30-34    05-Mar       yes          2   left
#
#   breast_quad irradiat                 class
# 0     left_up       no     recurrence-events
# 1     central       no  no-recurrence-events
# 2    left_low       no     recurrence-events
# 3    left_low      yes  no-recurrence-events
# 4    right_up       no     recurrence-events

# %%
#data types to confirm categorical columns
print(bc_df.dtypes, '\n')


#list of categorical columns
categorical_col = bc_df.select_dtypes('object').columns
categorical_col

# try to find unique values of each categorical column using a loop

for i_column in categorical_col:
    print(i_column, '\n', bc_df[i_column].unique(),'\n')
# Out:
# age            object
# menopause      object
# tumor_size     object
# inv_nodes      object
# node_caps      object
# deg_malig       int64
# breast         object
# breast_quad    object
# irradiat       object
# class          object
# dtype: object
#
# age
#  ['40-49' '50-59' '60-69' '30-39' '70-79' '20-29']
#
# menopause
#  ['premeno' 'ge40' 'lt40']
#
# tumor_size
#  ['15-19' '35-39' '30-34' '25-29' '40-44' '14-Oct' '0-4' '20-24' '45-49'
#  '50-54' '09-May']
#
# inv_nodes
#  ['0-2' '05-Mar' '15-17' '08-Jun' '11-Sep' '24-26' '14-Dec']
#
# node_caps
#  ['yes' 'no' 'a']
#
# breast
#  ['right' 'left']
#
# breast_quad
#  ['left_up' 'central' 'left_low' 'right_up' 'right_low' 'a']
#
# irradiat
#  ['no' 'yes']
#
# class
#  ['recurrence-events' 'no-recurrence-events']

# %% [markdown]
# ### Exercise 2 (Advanced) Apply the One Hot Encoder to the dataset

# %% [markdown]
# - Apply one hot encoding to the node-caps column and check the the correct number of columns have been returned.
# - Optional: Apply one hot encoding to all categorical columns.

# %%
#Import the required packages from sklearn
from sklearn.preprocessing import OneHotEncoder

# %%
# Initialize the ohe method
ohe = OneHotEncoder(sparse=False)

# Define the column names
col_names = ['node_caps']

# Fit and transform the data
bc_dummy_cols = ohe.fit_transform(bc_df[col_names])

# Get the feature names with the correct method (no need to pass bc_cols_prefix)
bc_dummy_names = ohe.get_feature_names_out()

# Convert to DataFrame
bc_dummy_cols = pd.DataFrame(bc_dummy_cols, columns=bc_dummy_names, dtype=int)

# Combine the encoded columns with the non-categorical columns
bc_encoded = pd.concat([bc_df, bc_dummy_cols], axis=1)

# Drop the original column to complete the transformation
bc_encoded = bc_encoded.drop(col_names, axis=1)

# Display the result
bc_encoded
# Out:
# c:\Users\alikp\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#        age menopause tumor_size inv_nodes  deg_malig breast breast_quad  \
# 0    40-49   premeno      15-19       0-2          3  right     left_up
# 1    50-59      ge40      15-19       0-2          1  right     central
# 2    50-59      ge40      35-39       0-2          2   left    left_low
# 3    40-49   premeno      35-39       0-2          3  right    left_low
# 4    40-49   premeno      30-34    05-Mar          2   left    right_up
# ..     ...       ...        ...       ...        ...    ...         ...
# 281  50-59      ge40      30-34    08-Jun          2   left    left_low
# 282  50-59   premeno      25-29    05-Mar          2   left    left_low
# ...

# %% [markdown]
# # Dealing with Skewed Data

# %% [markdown]
# ### Exercise 1 (Basic) - Identifying Skewedness of Variable

# %% [markdown]
# Task:
# - Import the phones dataset
# - Plot the battery life percentage column
# - identify the skewedness of the variable.

# %%
#Import the phones dataset
df_phone = pd.read_csv('phone_marketplace_dataset.csv')
df_phone
# Out:
#      price  year_made       name  battery_life_percentage  storage  \
# 0      551       2019  iPhone_11                       74       64
# 1      822       2020  iPhone_12                       94      128
# 2     1008       2022  iPhone_13                       97      256
# 3      881       2021  iPhone_14                       90      128
# 4      839       2020  iPhone_12                       91      256
# ..     ...        ...        ...                      ...      ...
# 344   1326       2022  iPhone_14                       91       64
# 345    458       2019  iPhone_11                       75      256
# 346    487       2019  iPhone_11                       87      256
# 347   1340       2022  iPhone_14                      100      256
# 348   1144       2021  iPhone_13                       94      128
#
#     magnet_charging marketplace  years_owned  visible_scratches  pro  \
# 0                no      kijiji            2                  9   no
# ...

# %%
# - Plot the battery life percentage column
sns.histplot(df_phone['battery_life_percentage'])
plt.show()
# Out:
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#identify the skewedness of the variable.
df_phone['battery_life_percentage'].skew()
# Out:
# -0.817025535352887

# %% [markdown]
# ### Exercise 2 (Advanced) - Experiment with Transformations

# %% [markdown]
# Before you begin, think about which transformations are likely to help make this variable more normal.
#
# Task:
# - In a new column, calculate the natural log of the battery life column
# - In a new column, calculate the log base 10 of the battery life column
# - In a new column, calculate the square oot of the battery life column.
# - In a new column, calculate the battery life column squared.
# - In a new column, calculate the battery life column cubed.
#
# - Plot the distributions on the same chart.
# - Calcuate the skewedness of the new columns.
# - Which one solved the skewedness most effectively?

# %%
# created new columns
df_phone['log_battery'] = np.log(df_phone['battery_life_percentage'])
df_phone['log10_battery'] = np.log10(df_phone['battery_life_percentage'])
df_phone['sqrt_battery'] = np.sqrt(df_phone['battery_life_percentage'])
df_phone['squared_battery'] = np.power(df_phone['battery_life_percentage'],2)
df_phone['cubed_battery'] = np.power(df_phone['battery_life_percentage'],3)
df_phone
# Out:
#      price  year_made       name  battery_life_percentage  storage  \
# 0      551       2019  iPhone_11                       74       64
# 1      822       2020  iPhone_12                       94      128
# 2     1008       2022  iPhone_13                       97      256
# 3      881       2021  iPhone_14                       90      128
# 4      839       2020  iPhone_12                       91      256
# ..     ...        ...        ...                      ...      ...
# 344   1326       2022  iPhone_14                       91       64
# 345    458       2019  iPhone_11                       75      256
# 346    487       2019  iPhone_11                       87      256
# 347   1340       2022  iPhone_14                      100      256
# 348   1144       2021  iPhone_13                       94      128
#
#     magnet_charging marketplace  years_owned  visible_scratches  pro  \
# 0                no      kijiji            2                  9   no
# ...

# %%
# list with the names of the 5 new columns
transform_cols = ['log_battery','log10_battery','sqrt_battery', 'squared_battery', 'cubed_battery']

# %%
# - Plot the distributions on the same chart.
for phone_new_col in transform_cols:
    sns.histplot(df_phone[phone_new_col])
    plt.show()
# Out:
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# - Calcuate the skewedness of the new columns.
for phone_new_col in transform_cols:
    print(phone_new_col + ": " + str(df_phone[phone_new_col].skew()))
# Out:
# log_battery: -0.9752812018882029
# log10_battery: -0.9752812018882534
# sqrt_battery: -0.896225285648387
# squared_battery: -0.6584633854237617
# cubed_battery: -0.5000973873265593

# %%
# # - Which one solved the skewedness most effectively?

# The initial skew of the battery column was -0.8170. 
# Therefore, only the squared and cubed columns improved the distribution. 
# In this case, when using skewness as a simple measure of normality, we would proceed with the cubed distribution.

# %% [markdown]
# # Dealing with Outliers

# %% [markdown]
# ### Exercise 1 (Basic) - Visualizing outliers

# %%
# Run this code to import the dataset for the exercise
df_basketball = pd.read_csv('basketball_stats.csv')
df_basketball
# Out:
#    first_name    last_name  points_per_game  reb_per_game  assist_per_game  \
# 0     Stephen        Larry               25             4                3
# 1      Lebron        Games               30            12               11
# 2     Grayson       Ballen               10             3                2
# 3        Luke       Dontik               35             9               10
# 4       Lonjo         Tall                7             6               10
# ..        ...          ...              ...           ...              ...
# 74      Chris  Rightington               19             5                3
# 75    Kameron      Johnson               10             3                1
# 76        Cam         Pain                8             1                4
# 77       Mike       Porter               18             6                2
# 78     Marcus       Lorris               12             4                1
#
#     3pt_per_game  steals_per_game  blocks_per_game position
# ...

# %%
basketball_boxplot_reb = sns.boxplot(data=df_basketball['reb_per_game'],orient='h')
basketball_boxplot_reb
# Out:
# <Axes: >

# %% [markdown]
# # Binning

# %% [markdown]
# ### Exercise 1: Binning a Histogram

# %% [markdown]
# Below is data of basketball players displaying their jumping attribute.

# %%
#import the basketball dataset
df_dunk = pd.read_csv('dunk_data.csv')
df_dunk
# Out:
#     height  weight  jump  athleticism  flex_score  dunk
# 0      194      85    41           16          56     1
# 1      206      88    35           28          79     1
# 2      188      71    44           77          35     1
# 3      183      96    43           70          24     1
# 4      181      89    20           76          86     0
# ..     ...     ...   ...          ...         ...   ...
# 73     198      97    36           99          84     1
# 74     182     102    34           86          27     0
# 75     190     110    29           96          74     0
# 76     194      96    40           92          34     1
# 77     190     101    34           43          69     1
#
# [78 rows x 6 columns]

# %%
# Display the unaltered distribution of the jump column
sns.histplot(df_dunk['jump'], discrete = True)
plt.show()
# Out:
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Display a binned version of the above histogram with 5 equal width bins
sns.histplot(df_dunk['jump'], bins = 5)
plt.show()
# Out:
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Exercise 2 (Advanced): Apply bins to training and testing data using Pandas

# %% [markdown]
# Below is data of basketball players displaying their attributes. Bin the height column to tall and very tall with a threshold of 2m.

# %%
#apply binning with the threshold of 2m to the height column
df_dunk = pd.read_csv('dunk_data.csv')
df_dunk
# Out:
#     height  weight  jump  athleticism  flex_score  dunk
# 0      194      85    41           16          56     1
# 1      206      88    35           28          79     1
# 2      188      71    44           77          35     1
# 3      183      96    43           70          24     1
# 4      181      89    20           76          86     0
# ..     ...     ...   ...          ...         ...   ...
# 73     198      97    36           99          84     1
# 74     182     102    34           86          27     0
# 75     190     110    29           96          74     0
# 76     194      96    40           92          34     1
# 77     190     101    34           43          69     1
#
# [78 rows x 6 columns]

# %%
labels = ['tall','vtall']
df_dunk['height_bin'], train_bins = pd.cut(df_dunk['height'],
                              [1,200,300],
                              labels = labels,
                              retbins= True)
df_dunk
# Out:
#     height  weight  jump  athleticism  flex_score  dunk height_bin
# 0      194      85    41           16          56     1       tall
# 1      206      88    35           28          79     1      vtall
# 2      188      71    44           77          35     1       tall
# 3      183      96    43           70          24     1       tall
# 4      181      89    20           76          86     0       tall
# ..     ...     ...   ...          ...         ...   ...        ...
# 73     198      97    36           99          84     1       tall
# 74     182     102    34           86          27     0       tall
# 75     190     110    29           96          74     0       tall
# 76     194      96    40           92          34     1       tall
# 77     190     101    34           43          69     1       tall
#
# [78 rows x 7 columns]

# %%
#apply binning with the threshold of 2m to the height column
df_dunk_test = pd.read_csv('dunk_data_test.csv')

# %%
#Note this code will not work by default. It is here to demonstrate syntax only.
df_dunk_test['height_bin'] = pd.cut(df_dunk_test['height'],
                              bins = train_bins,
                              labels = labels)
df_dunk_test.head()
# Out:
#    height  weight  jump  athleticism  flex_score  dunk height_bin
# 0     207      73    35           76          83     1      vtall
# 1     203      92    21           10          68     0      vtall
# 2     184     103    27           74          66     0       tall
# 3     196     110    20           86          49     0       tall
# 4     202      82    31           62          60     1      vtall

# %% [markdown]
# # Scaling Variables

# %% [markdown]
# ### Exercise 1 (Basic): Plot the distributions of the numeric variables in the customer experience dataset
# Using the below dataset, use plot each distribution so that you can see the different scales of each numeric variable. Notice the potential outliers that may affect our scaling.

# %%
#import dataset
df_cx = pd.read_csv('cx_survey_data.csv')
df_cx
# Out:
#      caseid        date    inquiry  wait_time  case_duration  sat_score  \
# 0         1  2021-11-28        Bug        680           3129          2
# 1         2  2021-12-03        Bug        745            246          6
# 2         3  2021-12-20        Bug       1199           2686          1
# 3         4  2021-10-02        Bug        205            591          4
# 4         5  2021-11-20        Bug         24           2327          2
# ..      ...         ...        ...        ...            ...        ...
# 164     165  2021-11-28  Discovery        989           1347          6
# 165     166  2021-09-06  Discovery        806           2512         10
# 166     167  2021-12-07  Discovery       1058            154          9
# 167     168  2021-11-26  Discovery        268            155          8
# 168     169  2021-10-07  Discovery         12            743          7
#
#      solved
# 0         0
# 1         1
# 2         0
# 3         1
# 4         0
# ..      ...
# ...

# %%
#define numeric columns to scale
scale_cols = df_cx.drop(['solved','caseid'], axis = 1).select_dtypes('number').columns

# %%
# plot a distribution of each numeric column

for feature in scale_cols:
    fig, (ax) = plt.subplots(1,1,figsize=(6,1))
    sns.histplot(df_cx[feature], ax = ax)
    plt.show()
# Out:
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alikp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Exercise 2 (Advanced): Apply Min Max Scaling to Training & Testing Data

# %% [markdown]
# In this exercise you're going to explore what impact an outlier in the training data might cause on the results of minmax scaling.

# %%
#fit and transform the min max scaler to the numeric columns
from sklearn.preprocessing import MinMaxScaler
minmax_scaler = MinMaxScaler()

df_cx_scaled = df_cx.copy()
df_cx_scaled[scale_cols] = minmax_scaler.fit_transform(df_cx_scaled[scale_cols])
df_cx_scaled.head()
# Out:
#    caseid        date inquiry  wait_time  case_duration  sat_score  solved
# 0       1  2021-11-28     Bug   0.563866       0.254026   0.111111       0
# 1       2  2021-12-03     Bug   0.618487       0.019522   0.555556       1
# 2       3  2021-12-20     Bug   1.000000       0.217993   0.000000       0
# 3       4  2021-10-02     Bug   0.164706       0.047584   0.333333       1
# 4       5  2021-11-20     Bug   0.012605       0.188791   0.111111       0

# %%
#Plot a scatter chart of the wait_time and case_duration columns before and after scaling on training and testing data
fig, (before, after) = plt.subplots(1, 2,figsize=(12,4))
before = df_cx.plot.scatter(ax = before, x='wait_time', y='case_duration', label = 'Before Scaling (training)', color = 'darkblue')
after = df_cx_scaled.plot.scatter(ax = after, x='wait_time', y='case_duration', label = 'After Scaling (training)', color= 'darkblue')

# %%
#import the cx_testing dataset and identify the numeric columns
df_cx_test = pd.read_csv('cx_survey_data_test.csv')

# %%
#make a copy of the testing data and transform the numeric columns using the minmax_scaler
df_cx_test_scaled = df_cx_test.copy()
df_cx_test_scaled[scale_cols] = minmax_scaler.transform(df_cx_test_scaled[scale_cols])

# %%
#Plot a scatter chart of the wait_time and case_duration columns before and after scaling on training and testing data
fig, (before, after) = plt.subplots(1, 2,figsize=(12,4))
before = df_cx_test.plot.scatter(ax = before, x='wait_time', y='case_duration', label = 'Before Scaling (testing)', color = 'orange')
after = df_cx_test_scaled.plot.scatter(ax = after, x='wait_time', y='case_duration', label = 'After Scaling (testing)', color= 'orange')
